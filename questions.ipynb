# %%
import os
import json
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
# Load the questions from the specified data file
questions = []

with open(os.getenv('DATA_FILE')) as f:
    questions = [json.loads(line) for line in f.readlines()]

# %%
questions

# %%
import os
import pandas as pd
from data_quality_assessment import generate_quality_report


df = pd.read_csv(os.getenv("DATA_FILE"))
report = generate_quality_report(df)
print(report)
# Out:
# c:\Users\dev\Dropbox\GitHub\data-analysis-agent\data_quality_assessment.py:1235: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results["skewness"] = float(stats.skew(numeric_series))
# c:\Users\dev\Dropbox\GitHub\data-analysis-agent\data_quality_assessment.py:1236: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results["kurtosis"] = float(stats.kurtosis(numeric_series))
# c:\Users\dev\Dropbox\GitHub\data-analysis-agent\data_quality_assessment.py:1659: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_series = pd.to_datetime(series, errors="coerce")
# ...
